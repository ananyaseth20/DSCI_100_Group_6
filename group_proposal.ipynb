# %% [markdown]
# **Credit Card Approvals**
#
# Introduction:
# This data has information concerning credit card applications. When reviewing credit card applications, many factors are considered, such as gender, age, debt history, year employed, etc, to check whether the applicant is a reliable and non-risky individual for the bank to approve a credit card. In this dataset, we will explore how the many variables may influence a bank’s decision to approve or reject a credit card application.

# %% [markdown]
# Our question for this project is whether we can predict which people in the dataset are successful in applying for a credit card.
# The data set we will be using is  Quinlan,J. R Credit Approval data set, linked here: Quinlan,J. R.. Credit Approval. UCI Machine Learning Repository. https://doi.org/10.24432/C5FS30
# This is a multivariate business dataset.
# The dataset we will be using has columns for:
# “Gender”, ”Age”, ”Debt”, ”Married”, ”BankCustomer”, ”Industry”, ”Ethnicity”, ”YearsEmployed”, ”PriorDefault”, ”Employed”, ”CreditScore”, ”DriversLicense”, ”Citizen”, ”ZipCode”, ”Income”, ”Approved”
# Which are mixtures of integers, real, and categorical variables that are used to determine whether someone gets approved for a credit card or not.

# %% [markdown]
# Preliminary exploratory data analysis:

# %%
### Run this cell before continuing.
import altair as alt
import numpy as np
import pandas as pd
from sklearn import set_config
from sklearn.compose import make_column_transformer
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    cross_validate,
    train_test_split,
)

# %% [markdown]
# (i) Reading data from the web into Python:

# %%
data = pd.read_csv('https://docs.google.com/spreadsheets/d/18Uxxd5YAfGLn4qWe5crLplKU19zPXPziaomAZLWpDyI/gviz/tq?tqx=out:csv&sheet=clean_dataset')

data
# Out:
#      Gender    Age    Debt  Married  BankCustomer         Industry Ethnicity  \
# 0         1  30.83   0.000        1             1      Industrials     White
# 1         0  58.67   4.460        1             1        Materials     Black
# 2         0  24.50   0.500        1             1        Materials     Black
# 3         1  27.83   1.540        1             1      Industrials     White
# 4         1  20.17   5.625        1             1      Industrials     White
# ..      ...    ...     ...      ...           ...              ...       ...
# 685       1  21.08  10.085        0             0        Education     Black
# 686       0  22.67   0.750        1             1           Energy     White
# 687       0  25.25  13.500        0             0       Healthcare    Latino
# 688       1  17.92   0.205        1             1  ConsumerStaples     White
# 689       1  35.00   3.375        1             1           Energy     Black
#
#      YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0             1.25             1         1            1               0
# 1             3.04             1         1            6               0
# 2             1.50             1         0            0               0
# 3             3.75             1         1            5               1
# 4             1.71             1         0            0               0
# ..             ...           ...       ...          ...             ...
# 685           1.25             0         0            0               0
# 686           2.00             0         1            2               1
# 687           2.00             0         1            1               1
# 688           0.04             0         0            0               0
# 689           8.29             0         0            0               1
#
#           Citizen  ZipCode  Income  Approved
# 0         ByBirth      202       0         1
# 1         ByBirth       43     560         1
# 2         ByBirth      280     824         1
# 3         ByBirth      100       3         1
# 4    ByOtherMeans      120       0         1
# ..            ...      ...     ...       ...
# 685       ByBirth      260       0         0
# 686       ByBirth      200     394         0
# 687       ByBirth      200       1         0
# 688       ByBirth      280     750         0
# 689       ByBirth        0       0         0
#
# [690 rows x 16 columns]

# %% [markdown]
# (ii) Cleaning and wrangling data:
# - We dropped the column that we deemed unnecesary: "DriversLicense"
# - We changed the values of "Gender", "Married", "PriorDefaut", "Employed", and "Approved" columns from 0s and 1s to something that we more appropriately felt captured the columns. This is because they were being treated like quantitative variables in terms of data analyses functions, and we felt that it would make the data more readable and user-friendly
# - We split the data further into 2 more datasets by gender (male and female) to help us better understand the effect of gender on credit card approvals

# %%
# clean and wrangle data:
data["Gender"] = data["Gender"].replace({
     0 : "Female",
     1 : "Male"
 })

data["Married"] = data["Married"].replace({
     0 : "No",
     1 : "Yes"
 })

data["PriorDefault"] = data["PriorDefault"].replace({
     0 : "No",
     1 : "Yes"
 })

data["Employed"] = data["Employed"].replace({
     0 : "No",
     1 : "Yes"
 })

data["Approved"] = data["Approved"].replace({
     0 : "No",
     1 : "Yes"
 })

data = data.drop('DriversLicense', axis=1)

data
# Out:
#      Gender    Age    Debt Married  BankCustomer         Industry Ethnicity  \
# 0      Male  30.83   0.000     Yes             1      Industrials     White
# 1    Female  58.67   4.460     Yes             1        Materials     Black
# 2    Female  24.50   0.500     Yes             1        Materials     Black
# 3      Male  27.83   1.540     Yes             1      Industrials     White
# 4      Male  20.17   5.625     Yes             1      Industrials     White
# ..      ...    ...     ...     ...           ...              ...       ...
# 685    Male  21.08  10.085      No             0        Education     Black
# 686  Female  22.67   0.750     Yes             1           Energy     White
# 687  Female  25.25  13.500      No             0       Healthcare    Latino
# 688    Male  17.92   0.205     Yes             1  ConsumerStaples     White
# 689    Male  35.00   3.375     Yes             1           Energy     Black
#
#      YearsEmployed PriorDefault Employed  CreditScore       Citizen  ZipCode  \
# 0             1.25          Yes      Yes            1       ByBirth      202
# 1             3.04          Yes      Yes            6       ByBirth       43
# 2             1.50          Yes       No            0       ByBirth      280
# 3             3.75          Yes      Yes            5       ByBirth      100
# 4             1.71          Yes       No            0  ByOtherMeans      120
# ..             ...          ...      ...          ...           ...      ...
# 685           1.25           No       No            0       ByBirth      260
# 686           2.00           No      Yes            2       ByBirth      200
# 687           2.00           No      Yes            1       ByBirth      200
# 688           0.04           No       No            0       ByBirth      280
# 689           8.29           No       No            0       ByBirth        0
#
#      Income Approved
# 0         0      Yes
# 1       560      Yes
# 2       824      Yes
# 3         3      Yes
# 4         0      Yes
# ..      ...      ...
# 685       0       No
# 686     394       No
# 687       1       No
# 688     750       No
# 689       0       No
#
# [690 rows x 15 columns]

# %%
male_data = data[data['Gender'] == 'Male']
male_data
# Out:
#     Gender    Age    Debt Married  BankCustomer               Industry  \
# 0     Male  30.83   0.000     Yes             1            Industrials
# 3     Male  27.83   1.540     Yes             1            Industrials
# 4     Male  20.17   5.625     Yes             1            Industrials
# 5     Male  32.08   4.000     Yes             1  CommunicationServices
# 6     Male  33.17   1.040     Yes             1              Transport
# ..     ...    ...     ...     ...           ...                    ...
# 683   Male  36.42   0.750      No             0            Real Estate
# 684   Male  40.58   3.290     Yes             1  CommunicationServices
# 685   Male  21.08  10.085      No             0              Education
# 688   Male  17.92   0.205     Yes             1        ConsumerStaples
# 689   Male  35.00   3.375     Yes             1                 Energy
#
#     Ethnicity  YearsEmployed PriorDefault Employed  CreditScore       Citizen  \
# 0       White          1.250          Yes      Yes            1       ByBirth
# 3       White          3.750          Yes      Yes            5       ByBirth
# 4       White          1.710          Yes       No            0  ByOtherMeans
# 5       White          2.500          Yes       No            0       ByBirth
# 6       Black          6.500          Yes       No            0       ByBirth
# ..        ...            ...          ...      ...          ...           ...
# 683     White          0.585           No       No            0       ByBirth
# 684     White          3.500           No       No            0  ByOtherMeans
# 685     Black          1.250           No       No            0       ByBirth
# 688     White          0.040           No       No            0       ByBirth
# 689     Black          8.290           No       No            0       ByBirth
#
#      ZipCode  Income Approved
# 0        202       0      Yes
# 3        100       3      Yes
# 4        120       0      Yes
# 5        360       0      Yes
# 6        164   31285      Yes
# ..       ...     ...      ...
# 683      240       3       No
# 684      400       0       No
# 685      260       0       No
# 688      280     750       No
# 689        0       0       No
#
# [480 rows x 15 columns]

# %%
female_data = data[data['Gender'] == 'Female']
female_data
# Out:
#      Gender    Age    Debt Married  BankCustomer               Industry  \
# 1    Female  58.67   4.460     Yes             1              Materials
# 2    Female  24.50   0.500     Yes             1              Materials
# 7    Female  22.92  11.585     Yes             1  InformationTechnology
# 12   Female  38.25   6.000     Yes             1             Financials
# 14   Female  45.83  10.500     Yes             1              Materials
# ..      ...    ...     ...     ...           ...                    ...
# 676  Female  30.58  10.665     Yes             1              Materials
# 678  Female  17.92  10.210     Yes             1             Healthcare
# 679  Female  20.08   1.250     Yes             1                 Energy
# 686  Female  22.67   0.750     Yes             1                 Energy
# 687  Female  25.25  13.500      No             0             Healthcare
#
#     Ethnicity  YearsEmployed PriorDefault Employed  CreditScore  Citizen  \
# 1       Black          3.040          Yes      Yes            6  ByBirth
# 2       Black          1.500          Yes       No            0  ByBirth
# 7       White          0.040          Yes       No            0  ByBirth
# 12      White          1.000          Yes       No            0  ByBirth
# 14      White          5.000          Yes      Yes            7  ByBirth
# ..        ...            ...          ...      ...          ...      ...
# 676     Black          0.085           No      Yes           12  ByBirth
# 678    Latino          0.000           No       No            0  ByBirth
# 679     White          0.000           No       No            0  ByBirth
# 686     White          2.000           No      Yes            2  ByBirth
# 687    Latino          2.000           No      Yes            1  ByBirth
#
#      ZipCode  Income Approved
# 1         43     560      Yes
# 2        280     824      Yes
# 7         80    1349      Yes
# 12         0       0      Yes
# 14         0       0      Yes
# ..       ...     ...      ...
# 676      129       3       No
# 678        0      50       No
# 679        0       0       No
# 686      200     394       No
# 687      200       1       No
#
# [210 rows x 15 columns]

# %% [markdown]
# (iii) Split the dataset into training and testing, and summarize it
# We summarized the data to show:
# - Count and non null columns
# - Description of quantitative variables (age, debt, bank customer, years employed, credit score, zip code, income)
# - Approval by gender
# - Means of predictor variables

# %%
data_train, data_test = train_test_split(data, test_size=0.25, random_state=123)

# %%
data_train
# Out:
#      Gender    Age    Debt Married  BankCustomer               Industry  \
# 618    Male  29.58   4.750     Yes             1  CommunicationServices
# 121    Male  25.67  12.500     Yes             1  InformationTechnology
# 352    Male  22.50  11.500      No             0  CommunicationServices
# 210    Male  39.33   5.875     Yes             1  InformationTechnology
# 299    Male  22.17  12.125     Yes             1                 Energy
# ..      ...    ...     ...     ...           ...                    ...
# 98   Female  22.50  11.000      No             0              Materials
# 322  Female  33.67   0.375     Yes             1  InformationTechnology
# 382  Female  24.33   2.500      No             0  ConsumerDiscretionary
# 365    Male  42.83   1.250     Yes             1  CommunicationServices
# 510    Male  13.75   4.000      No             0            Industrials
#
#     Ethnicity  YearsEmployed PriorDefault Employed  CreditScore  Citizen  \
# 618     White          2.000           No      Yes            1  ByBirth
# 121     White          1.210          Yes      Yes           67  ByBirth
# 352     White          1.500           No       No            0  ByBirth
# 210     Black         10.000          Yes      Yes           14  ByBirth
# 299     White          3.335           No      Yes            2  ByBirth
# ..        ...            ...          ...      ...          ...      ...
# 98      White          3.000          Yes       No            0  ByBirth
# 322     White          0.375           No       No            0  ByBirth
# 382     Asian          4.500           No       No            0  ByBirth
# 365     White         13.875           No      Yes            1  ByBirth
# 510     White          1.750          Yes      Yes            2  ByBirth
#
#      ZipCode  Income Approved
# 618      460      68       No
# 121      140     258      Yes
# 352        0    4000       No
# 210      399       0      Yes
# 299      180     173       No
# ..       ...     ...      ...
# 98       268       0       No
# 322      300      44      Yes
# 382      200     456       No
# 365      352     112       No
# 510      120    1000      Yes
#
# [517 rows x 15 columns]

# %%
data_test
# Out:
#     Gender    Age    Debt Married  BankCustomer               Industry  \
# 399   Male  31.00   2.085     Yes             1                 Energy
# 250   Male  40.25  21.500     Yes             1              Education
# 396   Male  29.83   2.040      No             0              Utilities
# 192   Male  41.75   0.960     Yes             1              Utilities
# 602   Male  29.83   1.250      No             0             Financials
# ..     ...    ...     ...     ...           ...                    ...
# 100   Male  37.50   1.750      No             0                 Energy
# 572   Male  21.92   0.540      No             0              Utilities
# 101   Male  35.25  16.500      No             0                 Energy
# 195   Male  28.25   5.040      No             0                 Energy
# 229   Male  22.08  11.000     Yes             1  InformationTechnology
#
#     Ethnicity  YearsEmployed PriorDefault Employed  CreditScore  Citizen  \
# 399     White          0.085           No       No            0  ByBirth
# 250     Other         20.000          Yes      Yes           11  ByBirth
# 396     Black          0.040           No       No            0  ByBirth
# 192     White          2.500          Yes       No            0  ByBirth
# 602     White          0.250           No       No            0  ByBirth
# ..        ...            ...          ...      ...          ...      ...
# 100     Asian          0.250          Yes       No            0  ByBirth
# 572     White          0.040          Yes      Yes            1  ByBirth
# 101     White          4.000          Yes       No            0  ByBirth
# 195     Asian          1.500          Yes      Yes            8  ByBirth
# 229     White          0.665          Yes       No            0  ByBirth
#
#      ZipCode  Income Approved
# 399      300       0       No
# 250        0    1200      Yes
# 396      128       1       No
# 192      510     600      Yes
# 602      224       0       No
# ..       ...     ...      ...
# 100      164     400       No
# 572      840      59      Yes
# 101       80       0       No
# 195      144       7      Yes
# 229      100       0      Yes
#
# [173 rows x 15 columns]

# %%
# data summary: non null columns
data_summary_info = data_train.info()
data_summary_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 517 entries, 618 to 510
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Gender         517 non-null    object
#  1   Age            517 non-null    float64
#  2   Debt           517 non-null    float64
#  3   Married        517 non-null    object
#  4   BankCustomer   517 non-null    int64
#  5   Industry       517 non-null    object
#  6   Ethnicity      517 non-null    object
#  7   YearsEmployed  517 non-null    float64
#  8   PriorDefault   517 non-null    object
#  9   Employed       517 non-null    object
#  10  CreditScore    517 non-null    int64
#  11  Citizen        517 non-null    object
#  12  ZipCode        517 non-null    int64
#  13  Income         517 non-null    int64
#  14  Approved       517 non-null    object
# dtypes: float64(3), int64(4), object(8)
# memory usage: 64.6+ KB

# %%
# data summary: description of quantitative variables (age, debt, bank customer, years employed, credit score, zip code, income)
data_summary_description = data_train.describe()
data_summary_description
# Out:
#               Age        Debt  BankCustomer  YearsEmployed  CreditScore  \
# count  517.000000  517.000000    517.000000     517.000000   517.000000
# mean    31.539110    4.573714      0.781431       2.287495     2.537718
# std     11.737083    4.889537      0.413675       3.343519     5.190651
# min     13.750000    0.000000      0.000000       0.000000     0.000000
# 25%     22.920000    0.875000      1.000000       0.250000     0.000000
# 50%     28.460000    2.710000      1.000000       1.000000     0.000000
# 75%     37.330000    6.665000      1.000000       3.000000     3.000000
# max     80.250000   28.000000      1.000000      28.500000    67.000000
#
#            ZipCode        Income
# count   517.000000    517.000000
# mean    187.667311    884.789168
# std     179.309381   3395.134308
# min       0.000000      0.000000
# 25%      75.000000      0.000000
# 50%     160.000000      4.000000
# 75%     280.000000    458.000000
# max    2000.000000  50000.000000

# %%
# data summary: approval by gender
data_summary_gender = data_train[['Gender', 'Approved']].value_counts()
data_summary_gender
# Out:
# Gender  Approved
# Male    No          201
#         Yes         155
# Female  No           87
#         Yes          74
# dtype: int64

# %%
# data summary: means of predictor variables
data_summary_means = pd.DataFrame()
data_summary_means['Approved'] = (data_train[data_train['Approved'] == 'Yes'].mean(numeric_only=True))
data_summary_means['Not Approved'] = (data_train[data_train['Approved'] == 'No'].mean(numeric_only=True))
data_summary_means
# Out:
#                   Approved  Not Approved
# Age              33.311485     30.129826
# Debt              5.694476      3.682552
# BankCustomer      0.851528      0.725694
# YearsEmployed     3.413035      1.392535
# CreditScore       4.820961      0.722222
# ZipCode         164.502183    206.086806
# Income         1752.209607    195.069444

# %% [markdown]
# (iv) Data visualization by:
# - Approvals by gender
# - Comparing the distributions of each of the predictor variables we plan to use in our analysis in a histogram

# %%
# data visualization: approvals by gender
data_vis_gender = alt.Chart(data_train).mark_bar().encode(
    x = alt.X('Gender'),
    y = alt.Y('count()'),
    color = alt.Color('Gender'),
).properties(
    height=100
).facet(
    "Approved:N",
)
data_vis_gender
# Out:
# alt.FacetChart(...)

# %%
# data visualization: comparing the distributions of each of the predictor variables we plan to use in our analysis
data_vis_predictors = data_train.hist()
data_vis_predictors
# Out:
# array([[<AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'Debt'}>,
#         <AxesSubplot: title={'center': 'BankCustomer'}>],
#        [<AxesSubplot: title={'center': 'YearsEmployed'}>,
#         <AxesSubplot: title={'center': 'CreditScore'}>,
#         <AxesSubplot: title={'center': 'ZipCode'}>],
#        [<AxesSubplot: title={'center': 'Income'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %% [markdown]
# Methods:
# - We will train a classification model to predict, given various factors, whether or not someone is likely to be approved or rejected for a credit card. We intend to keep all the columns in the dataset thus far. Still, we may add more columns using existing data later on, such as the percentage of ethnic groups in our data set, to see how that may influence our prediction outcomes.
# - We may use scatter plots and the facet function to visualize the relationship between two factors in the dataset in more detail.
# - We will also use bar graphs or pie charts to compare the relative amounts of one variable compared to another; for ex. How many males vs females get approved for credit cards?

# %% [markdown]
# Expected outcomes and significance:
#
#
# What do you expect to find?
# - We expect to find and explore perhaps a bias amongst the ethnicities who get approved for credit cards. We may also see a gender and class bias amongst those approved.
#
# What impact could such findings have?
# - These findings could help highlight any biases within the bank approval system, which can be used to improve this process and give individuals a more equal chance of obtaining a credit card, when their reason for rejection may be due to a prejudicial factor such as race or gender.
#
# What future questions could this lead to?
#
# Future questions could include:
#  - Identifying biases based on gender or ethnicity in credit card approval processes.
#  - How can we better the current system to allow everyone a fair chance for credit card approvals?
#  - To what scale does prior debt affect approval?
#  - Creating a tool to predict whether someone will get approved?
